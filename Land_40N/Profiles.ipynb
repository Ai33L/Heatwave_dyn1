# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import gzip
import pickle

p_std = np.arange(0.1, 9.9 ,0.2)[::-1]*10000

with gzip.open('/home/scratch/Abel_data/profilesv1', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)

current_index = 0
frac=[0,25,50,75,100]
Field='Meridional wind anomaly'

print(np.shape(WYa))
# Create the initial plot
mean=WYa[:,current_index,:].mean(axis=0)
std=WYa[:,current_index,:].std(axis=0)
fig, ax = plt.subplots()
fig.suptitle(Field)
             
line, = ax.plot(mean,p_std/100)
ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
ax.invert_yaxis()
ax.grid()
ax.set_title('Time - '+str(frac[current_index])+'%')
ax.set_xlim([-8, 20])
ax.set_xlabel('m/s')
ax.set_ylabel('hPa')
 
# Function to update the plot with the next portion of data
def update_plot(forward=True):
    global current_index
    
    step = 1 if forward else -1
    print(current_index)
    current_index += step
    if current_index < 0:
        current_index = 0
    elif current_index > 4:
        current_index = 4
    
    mean=WYa[:,current_index,:].mean(axis=0)
    std=WYa[:,current_index,:].std(axis=0)
    ax.cla()
    line, = ax.plot(mean,p_std/100)
    ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
    ax.invert_yaxis()
    ax.grid()
    ax.set_title('Time - '+str(frac[current_index])+'%')
    ax.set_xlim([-8, 20])
    ax.set_xlabel('m/s')
    ax.set_ylabel('hPa')
 
# Create buttons
ax_next_button = plt.axes([0.81, 0.01, 0.1, 0.05])
ax_prev_button = plt.axes([0.7, 0.01, 0.1, 0.05])
 
next_button = Button(ax_next_button, 'Next')
prev_button = Button(ax_prev_button, 'Previous')
 
# Connect buttons to update functions
next_button.on_clicked(lambda event: update_plot(forward=True))
prev_button.on_clicked(lambda event: update_plot(forward=False))
 
# Show the plot
plt.show()
# Out:
# (1558, 5, 49)
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import gzip
import pickle

p_std = np.arange(0.1, 9.9 ,0.2)[::-1]*10000

with gzip.open('/home/scratch/Abel_data/profilesv1', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)

for i in range(len(heat_index)):
    
    int_list.append(heat_index[i][3])
    dur_list.append(heat_index[i][4])
    a_list.append(WXa[i])
    
cut=np.quantile(dur_list,[0,0.1,0.45,0.55,0.9,1])

dur_sel=[]
int_sel=[]
a_sel=[]

for i in range(len(a_list)):
    if (dur_list[i]>=cut[4]  and dur_list[i]<=cut[5]):
        dur_sel.append(dur_list[i])
        int_sel.append(int_list[i])
        a_sel.append(a_list[i])

a_sel=np.array(a_sel)
print(len(a_sel))

current_index = 0
frac=[0,25,50,75,100]
Field='Zonal wind anomaly'

# Create the initial plot
mean=a_sel[:,current_index,:].mean(axis=0)
std=a_sel[:,current_index,:].std(axis=0)
fig, ax = plt.subplots()
fig.suptitle(Field)
             
line, = ax.plot(mean,p_std/100)
ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
ax.invert_yaxis()
ax.grid()
ax.set_title('Time - '+str(frac[current_index])+'%')
ax.set_xlim([-10, 10])
ax.set_xlabel('m/s')
ax.set_ylabel('hPa')
 
# Function to update the plot with the next portion of data
def update_plot(forward=True):
    global current_index
    
    step = 1 if forward else -1
    print(current_index)
    current_index += step
    if current_index < 0:
        current_index = 0
    elif current_index > 4:
        current_index = 4
    
    mean=a_sel[:,current_index,:].mean(axis=0)
    std=a_sel[:,current_index,:].std(axis=0)
    ax.cla()
    line, = ax.plot(mean,p_std/100)
    ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
    ax.invert_yaxis()
    ax.grid()
    ax.set_title('Time - '+str(frac[current_index])+'%')
    ax.set_xlim([-10, 10])
    ax.set_xlabel('m/s')
    ax.set_ylabel('hPa')
 
# Create buttons
ax_next_button = plt.axes([0.81, 0.01, 0.1, 0.05])
ax_prev_button = plt.axes([0.7, 0.01, 0.1, 0.05])
 
next_button = Button(ax_next_button, 'Next')
prev_button = Button(ax_prev_button, 'Previous')
 
# Connect buttons to update functions
next_button.on_clicked(lambda event: update_plot(forward=True))
prev_button.on_clicked(lambda event: update_plot(forward=False))
 
# Show the plot
plt.show()
# Out:
# 468
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import gzip
import pickle

p_std = np.arange(0.1, 9.9 ,0.2)[::-1]*10000

with gzip.open('/home/scratch/Abel_data/profilesv1', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)

current_index = 0
frac=[0,25,50,75,100]
Field='Verical wind anomaly'

# Create the initial plot
mean=WZa[:,current_index,:].mean(axis=0)
std=WZa[:,current_index,:].std(axis=0)
fig, ax = plt.subplots()
fig.suptitle(Field)
             
line, = ax.plot(mean,p_std/100)
ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
ax.invert_yaxis()
ax.grid()
ax.set_title('Time - '+str(frac[current_index])+'%')
ax.set_xlim([-0.1, 0.1])
ax.set_xlabel('hPa/s')
ax.set_ylabel('hPa')
 
# Function to update the plot with the next portion of data
def update_plot(forward=True):
    global current_index
    
    step = 1 if forward else -1
    print(current_index)
    current_index += step
    if current_index < 0:
        current_index = 0
    elif current_index > 4:
        current_index = 4
    
    mean=WZa[:,current_index,:].mean(axis=0)
    std=WZa[:,current_index,:].std(axis=0)
    ax.cla()
    line, = ax.plot(mean,p_std/100)
    ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
    ax.invert_yaxis()
    ax.grid()
    ax.set_title('Time - '+str(frac[current_index])+'%')
    ax.set_xlim([-0.1, 0.1])
    ax.set_xlabel('Pa/s')
    ax.set_ylabel('hPa')
 
# Create buttons
ax_next_button = plt.axes([0.81, 0.01, 0.1, 0.05])
ax_prev_button = plt.axes([0.7, 0.01, 0.1, 0.05])
 
next_button = Button(ax_next_button, 'Next')
prev_button = Button(ax_prev_button, 'Previous')
 
# Connect buttons to update functions
next_button.on_clicked(lambda event: update_plot(forward=True))
prev_button.on_clicked(lambda event: update_plot(forward=False))
 
# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import gzip
import pickle

p_std = np.arange(0.1, 9.9 ,0.2)[::-1]*10000

with gzip.open('/home/scratch/Abel_data/heat_indexv1', 'rb') as f:
    heat_index= pickle.load(f)
    
with gzip.open('/home/scratch/Abel_data/profilesv1', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)

int_list=[]
dur_list=[]
a_list=[]

for i in range(len(heat_index)):
    
    int_list.append(heat_index[i][3])
    dur_list.append(heat_index[i][4])
    a_list.append(DXa[i])
    
cut=np.quantile(int_list,[0,0.1,0.45,0.55,0.9,1])

dur_sel=[]
int_sel=[]
a_sel=[]

for i in range(len(a_list)):
    if (int_list[i]>=cut[4]  and int_list[i]<=cut[5]):
        dur_sel.append(dur_list[i])
        int_sel.append(int_list[i])
        a_sel.append(a_list[i])

a_sel=np.array(a_sel)
print(len(a_sel))

current_index = 0
frac=[0,25,50,75,100]
Field='DSEx anomaly gradient'

# Create the initial plot
mean=a_sel[:,current_index,:].mean(axis=0)
std=a_sel[:,current_index,:].std(axis=0)
fig, ax = plt.subplots()
fig.suptitle(Field)
             
line, = ax.plot(mean,p_std/100)
ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
ax.invert_yaxis()
ax.grid()
ax.set_title('Time - '+str(frac[current_index])+'%')
ax.set_xlim([-0.01, 0.01])
ax.set_xlabel('J/kg.m')
ax.set_ylabel('hPa')
 
# Function to update the plot with the next portion of data
def update_plot(forward=True):
    global current_index
    
    step = 1 if forward else -1
    print(current_index)
    current_index += step
    if current_index < 0:
        current_index = 0
    elif current_index > 4:
        current_index = 4
    
    mean=a_sel[:,current_index,:].mean(axis=0)
    std=a_sel[:,current_index,:].std(axis=0)
    ax.cla()
    line, = ax.plot(mean,p_std/100)
    ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
    ax.invert_yaxis()
    ax.grid()
    ax.set_title('Time - '+str(frac[current_index])+'%')
    ax.set_xlim([-0.01, 0.01])
    ax.set_xlabel('J/kg.m')
    ax.set_ylabel('hPa')
 
# Create buttons
ax_next_button = plt.axes([0.81, 0.01, 0.1, 0.05])
ax_prev_button = plt.axes([0.7, 0.01, 0.1, 0.05])
 
next_button = Button(ax_next_button, 'Next')
prev_button = Button(ax_prev_button, 'Previous')
 
# Connect buttons to update functions
next_button.on_clicked(lambda event: update_plot(forward=True))
prev_button.on_clicked(lambda event: update_plot(forward=False))
 
# Show the plot
plt.show()
# Out:
# 156
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import gzip
import pickle

p_std = np.arange(0.1, 9.9 ,0.2)[::-1]*10000

with gzip.open('/home/scratch/Abel_data/profilesv1', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)

current_index = 0
frac=[0,25,50,75,100]
Field='DSEy anomaly gradient'

# Create the initial plot
mean=DYa[:,current_index,:].mean(axis=0)
std=DYa[:,current_index,:].std(axis=0)
fig, ax = plt.subplots()
fig.suptitle(Field)
             
line, = ax.plot(mean,p_std/100)
ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
ax.invert_yaxis()
ax.grid()
ax.set_title('Time - '+str(frac[current_index])+'%')
ax.set_xlim([-0.01, 0.01])
ax.set_xlabel('J/kg.hPa')
ax.set_ylabel('hPa')
 
# Function to update the plot with the next portion of data
def update_plot(forward=True):
    global current_index
    
    step = 1 if forward else -1
    print(current_index)
    current_index += step
    if current_index < 0:
        current_index = 0
    elif current_index > 4:
        current_index = 4
    
    mean=DYa[:,current_index,:].mean(axis=0)
    std=DYa[:,current_index,:].std(axis=0)
    ax.cla()
    line, = ax.plot(mean,p_std/100)
    ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
    ax.invert_yaxis()
    ax.grid()
    ax.set_title('Time - '+str(frac[current_index])+'%')
    ax.set_xlim([-0.01, 0.01])
    ax.set_xlabel('J/kg.m')
    ax.set_ylabel('hPa')
 
# Create buttons
ax_next_button = plt.axes([0.81, 0.01, 0.1, 0.05])
ax_prev_button = plt.axes([0.7, 0.01, 0.1, 0.05])
 
next_button = Button(ax_next_button, 'Next')
prev_button = Button(ax_prev_button, 'Previous')
 
# Connect buttons to update functions
next_button.on_clicked(lambda event: update_plot(forward=True))
prev_button.on_clicked(lambda event: update_plot(forward=False))
 
# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import gzip
import pickle

p_std = np.arange(0.1, 9.9 ,0.2)[::-1]*10000

with gzip.open('/home/scratch/Abel_data/profilesv1', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)

current_index = 0
frac=[0,25,50,75,100]
Field='DSEz anomaly gradient'

# Create the initial plot
mean=DZa[:,current_index,:].mean(axis=0)
std=DZa[:,current_index,:].std(axis=0)
fig, ax = plt.subplots()
fig.suptitle(Field)
             
line, = ax.plot(mean,p_std/100)
ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
ax.invert_yaxis()
ax.grid()
ax.set_title('Time - '+str(frac[current_index])+'%')
ax.set_xlim([-1, 1])
ax.set_xlabel('J/kg.hPa')
ax.set_ylabel('hPa')
 
# Function to update the plot with the next portion of data
def update_plot(forward=True):
    global current_index
    
    step = 1 if forward else -1
    print(current_index)
    current_index += step
    if current_index < 0:
        current_index = 0
    elif current_index > 4:
        current_index = 4
    
    mean=DZa[:,current_index,:].mean(axis=0)
    std=DZa[:,current_index,:].std(axis=0)
    ax.cla()
    line, = ax.plot(mean,p_std/100)
    ax.fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
    ax.invert_yaxis()
    ax.grid()
    ax.set_title('Time - '+str(frac[current_index])+'%')
    ax.set_xlim([-1, 1])
    ax.set_xlabel('J/kg.Pa')
    ax.set_ylabel('hPa')
 
# Create buttons
ax_next_button = plt.axes([0.81, 0.01, 0.1, 0.05])
ax_prev_button = plt.axes([0.7, 0.01, 0.1, 0.05])
 
next_button = Button(ax_next_button, 'Next')
prev_button = Button(ax_prev_button, 'Previous')
 
# Connect buttons to update functions
next_button.on_clicked(lambda event: update_plot(forward=True))
prev_button.on_clicked(lambda event: update_plot(forward=False))
 
# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
with gzip.open('/home/scratch/Abel_data/profilesv1', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)
    
plt.plot(windxmean,p_std)
plt.gca().invert_yaxis()
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
with gzip.open('/home/scratch/Abel_data/profilesv1', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)
    
plt.plot(DSEzmean,p_std)
plt.gca().invert_yaxis()
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import gzip
import pickle

p_std = np.arange(0.1, 9.9 ,0.2)[::-1]*10000

fig, ax = plt.subplots(2, 5, sharex=True, sharey=True)
fig.set_size_inches(12, 6)

with gzip.open('/home/scratch/Abel_data/heat_indexv3', 'rb') as f:
    heat_index= pickle.load(f)
    
with gzip.open('/home/scratch/Abel_data/profilesv3', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)

int_list=[]
dur_list=[]
a_list=[]

for i in range(len(heat_index)):
    
    int_list.append(heat_index[i][3])
    dur_list.append(heat_index[i][4])
    a_list.append(DXa[i])
    
cut=np.quantile(int_list,[0,0.1,0.45,0.55,0.9,1])

dur_sel=[]
int_sel=[]
a_sel=[]

for i in range(len(a_list)):
    if (int_list[i]>=cut[4]  and int_list[i]<=cut[5]):
        dur_sel.append(dur_list[i])
        int_sel.append(int_list[i])
        a_sel.append(a_list[i])

a_sel=np.array(a_sel)
print(len(a_sel))

current_index = 0
frac=[0,25,50,75,100]
Field='DSEx anomaly gradient'

for current_index in range(len(frac)):
    # Create the initial plot
    mean=a_sel[:,current_index,:].mean(axis=0)
    std=a_sel[:,current_index,:].std(axis=0)

    ax[0][current_index].plot(mean,p_std/100)
    ax[0][current_index].fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
    ax[0][current_index].invert_yaxis()
    ax[0][current_index].grid()
#     ax.set_title('Time - '+str(frac[current_index])+'%')
#     ax.set_xlim([-0.01, 0.01])
#     ax.set_xlabel('J/kg.m')
#     ax.set_ylabel('hPa')

#################################################################################

int_list=[]
dur_list=[]
a_list=[]

for i in range(len(heat_index)):
    
    int_list.append(heat_index[i][3])
    dur_list.append(heat_index[i][4])
    a_list.append(DXa[i])
    
cut=np.quantile(dur_list,[0,0.1,0.45,0.55,0.9,1])

dur_sel=[]
int_sel=[]
a_sel=[]

for i in range(len(a_list)):
    if (dur_list[i]>=cut[4]  and dur_list[i]<=cut[5]):
        dur_sel.append(dur_list[i])
        int_sel.append(int_list[i])
        a_sel.append(a_list[i])

a_sel=np.array(a_sel)
print(len(a_sel))

current_index = 0
frac=[0,25,50,75,100]
Field='DSEx anomaly gradient'

for current_index in range(len(frac)):
    # Create the initial plot
    mean=a_sel[:,current_index,:].mean(axis=0)
    std=a_sel[:,current_index,:].std(axis=0)

    ax[1][current_index].plot(mean,p_std/100)
    ax[1][current_index].fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
#     ax[1][current_index].invert_yaxis()
    ax[1][current_index].grid()
    
fig.supxlabel('J/kg.m')
fig.supylabel('hPa')

ax[1][0].set_ylabel('High duration')
ax[0][0].set_ylabel('High intensity')

ax[1][0].set_xlabel('0%')
ax[1][1].set_xlabel('25%')
ax[1][2].set_xlabel('50%')
ax[1][3].set_xlabel('75%')
ax[1][4].set_xlabel('100%')

plt.suptitle(Field)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1200">
# 188
# 188

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import gzip
import pickle

p_std = np.arange(0.1, 9.9 ,0.2)[::-1]*10000

fig, ax = plt.subplots(2, 5, sharex=True, sharey=True)
fig.set_size_inches(12, 6)

with gzip.open('/home/scratch/Abel_data/heat_indexv3', 'rb') as f:
    heat_index= pickle.load(f)
    
with gzip.open('/home/scratch/Abel_data/profilesv3', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)

int_list=[]
dur_list=[]
a_list=[]

for i in range(len(heat_index)):
    
    int_list.append(heat_index[i][3])
    dur_list.append(heat_index[i][4])
    a_list.append(WXa[i])
    
cut=np.quantile(int_list,[0,0.1,0.45,0.55,0.9,1])

dur_sel=[]
int_sel=[]
a_sel=[]

for i in range(len(a_list)):
    if (int_list[i]>=cut[4]  and int_list[i]<=cut[5]):
        dur_sel.append(dur_list[i])
        int_sel.append(int_list[i])
        a_sel.append(a_list[i])

a_sel=np.array(a_sel)
print(len(a_sel))

current_index = 0
frac=[0,25,50,75,100]
Field='DSEx anomaly gradient'

for current_index in range(len(frac)):
    # Create the initial plot
    mean=a_sel[:,current_index,:].mean(axis=0)
    std=a_sel[:,current_index,:].std(axis=0)

    ax[0][current_index].plot(mean,p_std/100)
    ax[0][current_index].fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
    ax[0][current_index].invert_yaxis()
    ax[0][current_index].grid()
#     ax.set_title('Time - '+str(frac[current_index])+'%')
#     ax.set_xlim([-0.01, 0.01])
#     ax.set_xlabel('J/kg.m')
#     ax.set_ylabel('hPa')

#################################################################################

int_list=[]
dur_list=[]
a_list=[]

for i in range(len(heat_index)):
    
    int_list.append(heat_index[i][3])
    dur_list.append(heat_index[i][4])
    a_list.append(WXa[i])
    
cut=np.quantile(dur_list,[0,0.1,0.45,0.55,0.9,1])

dur_sel=[]
int_sel=[]
a_sel=[]

for i in range(len(a_list)):
    if (dur_list[i]>=cut[4]  and dur_list[i]<=cut[5]):
        dur_sel.append(dur_list[i])
        int_sel.append(int_list[i])
        a_sel.append(a_list[i])

a_sel=np.array(a_sel)
print(len(a_sel))

current_index = 0
frac=[0,25,50,75,100]
Field='Zonal wind anomaly'

for current_index in range(len(frac)):
    # Create the initial plot
    mean=a_sel[:,current_index,:].mean(axis=0)
    std=a_sel[:,current_index,:].std(axis=0)

    ax[1][current_index].plot(mean,p_std/100)
    ax[1][current_index].fill_betweenx(p_std/100, mean-std,mean+std, alpha =0.2)
#     ax[1][current_index].invert_yaxis()
    ax[1][current_index].grid()
    
fig.supxlabel('m/s')
fig.supylabel('hPa')

ax[1][0].set_ylabel('High duration')
ax[0][0].set_ylabel('High intensity')

ax[1][0].set_xlabel('0%')
ax[1][1].set_xlabel('25%')
ax[1][2].set_xlabel('50%')
ax[1][3].set_xlabel('75%')
ax[1][4].set_xlabel('100%')

plt.suptitle(Field)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1200">
# 188
# 188

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import gzip
import pickle

p_std = np.arange(0.1, 9.9 ,0.2)[::-1]*10000
fig, ax = plt.subplots(1, 2, sharex=True, sharey=True)
fig.set_size_inches(8, 4.5)

with gzip.open('/home/scratch/Abel_data/heat_indexv3', 'rb') as f:
    heat_index= pickle.load(f)
    
with gzip.open('/home/scratch/Abel_data/profilesv3', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)

int_list=[]
dur_list=[]
a_list=[]
b_list=[]

for i in range(len(heat_index)):
    
    int_list.append(heat_index[i][3])
    dur_list.append(heat_index[i][4])
    a_list.append(WXa[i])
    b_list.append(DXa[i])
    
cut=np.quantile(int_list,[0,0.1,0.45,0.55,0.9,1])
cut2=np.quantile(int_list,[0,0.1,0.45,0.55,0.997,1])

dur_sel=[]
int_sel=[]
a_sel=[]
b_sel=[]

color_list=['firebrick', 'red', 'blue', 'mediumblue']

for i in range(len(a_list)):
    if (int_list[i]>=cut[4]  and int_list[i]<=cut[5]):
        dur_sel.append(dur_list[i])
        int_sel.append(int_list[i])
        a_sel.append(a_list[i])
        b_sel.append(b_list[i])
    if (int_list[i]>=cut2[4]  and int_list[i]<=cut2[5]):
        for l in range(4):
            ax[0].plot(a_list[i][l:l+2,0], b_list[i][l:l+2,0], color=color_list[l])

dse_list=[]
wind_list=[]

for i in range(len(a_sel)):
    for e in a_sel[i]:
        wind_list.append(e[0])
    for e in b_sel[i]:
        dse_list.append(e[0])

ax[0].hist2d(wind_list, dse_list, density=True, bins=10, vmin=0, vmax=20, cmap='Blues')

#####################################################

int_list=[]
dur_list=[]
a_list=[]
b_list=[]

for i in range(len(heat_index)):
    
    int_list.append(heat_index[i][3])
    dur_list.append(heat_index[i][4])
    a_list.append(WXa[i])
    b_list.append(DXa[i])
    
cut=np.quantile(dur_list,[0,0.1,0.45,0.55,0.9,1])
cut2=np.quantile(dur_list,[0,0.1,0.45,0.55,0.997,1])


dur_sel=[]
int_sel=[]
a_sel=[]
b_sel=[]

for i in range(len(a_list)):
    if (dur_list[i]>=cut[4]  and dur_list[i]<=cut[5]):
        dur_sel.append(dur_list[i])
        int_sel.append(int_list[i])
        a_sel.append(a_list[i])
        b_sel.append(b_list[i])
    if (dur_list[i]>=cut2[4]  and dur_list[i]<=cut2[5]):
        for l in range(4):
            ax[1].plot(a_list[i][l:l+2,0], b_list[i][l:l+2,0], color=color_list[l])

dse_list=[]
wind_list=[]

for i in range(len(a_sel)):
    for e in a_sel[i]:
        wind_list.append(e[0])
    for e in b_sel[i]:
        dse_list.append(e[0])

ax[1].hist2d(wind_list, dse_list, density=True, bins=10, vmin=0, vmax=20, cmap='Blues')
fig.supxlabel('m/s')
fig.supylabel('J/kg.m')

ax[1].set_xlabel('High duration')
ax[0].set_xlabel('High intensity')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import gzip
import pickle

p_std = np.arange(0.1, 9.9 ,0.2)[::-1]*10000
# fig, ax = plt.subplots(1, 1, sharex=True, sharey=True)
# fig.set_size_inches(5, 4.5)

with gzip.open('/home/scratch/Abel_data/heat_indexv3', 'rb') as f:
    heat_index= pickle.load(f)
    
with gzip.open('/home/scratch/Abel_data/profilesv3', 'rb') as f:
    WXa, WYa, WZa, DXa, DYa, DZa, windxmean, windymean, windzmean, DSExmean, DSEymean, DSEzmean=pickle.load(f)

int_list=[]
dur_list=[]
a_list=[]
b_list=[]

for i in range(len(heat_index)):
    
    int_list.append(heat_index[i][3])
    dur_list.append(heat_index[i][4])
    a_list.append(WXa[i])
    b_list.append(DXa[i])
    
cut=np.quantile(int_list,[0,0.1,0.45,0.55,0.997,1])

dur_sel=[]
int_sel=[]
a_sel=[]
b_sel=[]

a_list=np.array(a_list)
b_list=np.array(b_list)

for i in range(len(a_list)):
    if (int_list[i]>=cut[4]  and int_list[i]<=cut[5]):
        dur_sel.append(dur_list[i])
        int_sel.append(int_list[i])
        plt.plot(a_list[i][:,0], b_list[i][:,0], color='red')
        plt.scatter(a_list[i][:,0][0], b_list[i][:,0][0], marker='o', color='red')

print(len(dur_sel))
#####################################################

int_list=[]
dur_list=[]
a_list=[]
b_list=[]

for i in range(len(heat_index)):
    
    int_list.append(heat_index[i][3])
    dur_list.append(heat_index[i][4])
    a_list.append(WXa[i])
    b_list.append(DXa[i])
    
cut=np.quantile(dur_list,[0,0.1,0.45,0.55,0.997,1])

dur_sel=[]
int_sel=[]
a_sel=[]
b_sel=[]

for i in range(len(a_list)):
    if (dur_list[i]>=cut[4]  and dur_list[i]<=cut[5]):
        dur_sel.append(dur_list[i])
        int_sel.append(int_list[i])
        plt.plot(a_list[i][:,0], b_list[i][:,0], color='blue')
        plt.scatter(a_list[i][:,0][0], b_list[i][:,0][0], marker='o', color='blue')

plt.plot([],[], color='red', label='Intense heatwave')
plt.plot([],[], color='blue', label='Long heatwave')

print(len(dur_sel))
plt.xlabel('u_prime (m/s)')
plt.ylabel('DSE gradient (J/kg.m)')

plt.legend()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# 6
# 6

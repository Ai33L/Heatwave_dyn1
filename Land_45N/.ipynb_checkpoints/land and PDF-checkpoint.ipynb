# %%
# %matplotlib notebook
import gzip
import pickle
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

import os
os.chdir('/home/scratch/Abel_data') 

common=xr.open_zarr("common")
    
lon=common['longitude'].values[:]
lat=common['latitude'].values[:]
Area_type=common['area_type'].values[:]

plt.contourf(lon, lat, Area_type.astype(str)=='land', cmap='Paired')

with gzip.open('obs_mask10', 'rb') as f:
    mask= pickle.load(f)

lon_mask=np.arange(100,110,1)
lat_mask=np.arange(41,50,1)
    
plt.contourf(lon_mask, lat_mask, np.ones((9,10)), hatches=['////////'], alpha=0.2)

plt.ylabel('Lat')
plt.xlabel('Lon')
plt.savefig('/home/data/lab_abel/Paper1/land', bbox_inches='tight',dpi=900)

# %%
# %matplotlib notebook
import gzip
import pickle
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr


# fig, axs = plt.subplots(1, 2, figsize=(9, 3.5))
fig, axs = plt.subplots(1, 2, figsize=(9, 3.5), gridspec_kw={'width_ratios': [1.25, 1]})
# Remove horizontal space between axes

import os
os.chdir('/home/scratch/Abel_data') 

common=xr.open_zarr("common")
    
lon=common['longitude'].values[:]
lat=common['latitude'].values[:]
Area_type=common['area_type'].values[:]

axs[0].contourf(lon, lat, Area_type.astype(str)=='land', cmap='Paired')

with gzip.open('obs_mask10', 'rb') as f:
    mask= pickle.load(f)

lon_mask=np.arange(100,110,1)
lat_mask=np.arange(41,50,1)
    
axs[0].contourf(lon_mask, lat_mask, np.ones((9,10)), hatches=['////////'], alpha=0.2)

axs[0].set(xlabel='Lon',ylabel='Lat')

############################################################################################################


import warnings
warnings.filterwarnings("ignore")
import scipy
import pickle
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.graphics import tsaplots
import gzip
import seaborn

lat1=14
lat2=18
lon1=36
lon2=40

common=xr.open_zarr("/home/scratch/Abel_data/long_run2/common",consolidated=False)
lat=np.radians(common['latitude']).sel(lat=range(lat1,lat2),lon=range(lon1,lon2)).values[:]

st=0
temp_field=0
for i in range(1,5):
    for j in range(1,21):
        D=xr.open_zarr("/home/scratch/Abel_data/long_run2/run"+str(i)+"/year"+str(j),consolidated=False)
        if st==0:
            temp_field=D['air_temperature'][:,0].sel(lat=range(lat1,lat2),lon=range(lon1,lon2)).values[:]
            st=1
        elif st==1:
            temp_field = np.concatenate((temp_field, 
                                         D['air_temperature'][:,0].sel(lat=range(lat1,lat2),lon=range(lon1,lon2))), axis=0)

T=(temp_field*np.cos(lat)).sum(axis=(1,2))/(np.cos(lat).sum())

import os
os.chdir('/home/scratch/Abel_data/long_run2')  

# with gzip.open('A_comb', 'rb') as f:
#     T=pickle.load(f)[:]

seaborn.distplot(ax=axs[1], a=T, kde=True, hist=False, label='long_run', color='red')
print(np.mean(T), np.std(T), scipy.stats.skew(T))

axs[1].set(xlabel='$T_{a}$ (K)',ylabel='PDF')
axs[1].grid()

plt.tight_layout()
plt.savefig('/home/data/lab_abel/Paper1/land', bbox_inches='tight',dpi=900)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_91543/2681672552.py in <module>
#      57 for i in range(1,51):
#      58     for j in range(1,21):
# ---> 59         D=xr.open_zarr("/home/scratch/Abel_data/long_run2/run"+str(i)+"/year"+str(j),consolidated=False)
#      60         if st==0:
#      61             temp_field=D['air_temperature'][:,0].sel(lat=range(lat1,lat2),lon=range(lon1,lon2)).values[:]
#
# /home/data/miniconda3/lib/python3.8/site-packages/xarray/backends/zarr.py in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, chunk_store, storage_options, decode_timedelta, use_cftime, **kwargs)
#     768     }
#     769
# --> 770     ds = open_dataset(
#     771         filename_or_obj=store,
#     772         group=group,
#
# /home/data/miniconda3/lib/python3.8/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, backend_kwargs, *args, **kwargs)
#     501         **kwargs,
#     502     )
# --> 503     ds = _dataset_from_backend_dataset(
#     504         backend_ds,
#     505         filename_or_obj,
#
# /home/data/miniconda3/lib/python3.8/site-packages/xarray/backends/api.py in _dataset_from_backend_dataset(backend_ds, filename_or_obj, engine, chunks, cache, overwrite_encoded_chunks, **extra_tokens)
#     317         ds = backend_ds
#     318     else:
# --> 319         ds = _chunk_ds(
#     320             backend_ds,
#     321             filename_or_obj,
#
# /home/data/miniconda3/lib/python3.8/site-packages/xarray/backends/api.py in _chunk_ds(backend_ds, filename_or_obj, engine, chunks, overwrite_encoded_chunks, **extra_tokens)
#     288     for name, var in backend_ds.variables.items():
#     289         var_chunks = _get_chunk(var, chunks)
# --> 290         variables[name] = _maybe_chunk(
#     291             name,
#     292             var,
#
# /home/data/miniconda3/lib/python3.8/site-packages/xarray/core/dataset.py in _maybe_chunk(name, var, chunks, token, lock, name_prefix, overwrite_encoded_chunks)
#     435         token2 = tokenize(name, token if token else var._data, chunks)
#     436         name2 = f"{name_prefix}{name}-{token2}"
# --> 437         var = var.chunk(chunks, name=name2, lock=lock)
#     438
#     439         if overwrite_encoded_chunks and var.chunks is not None:
#
# /home/data/miniconda3/lib/python3.8/site-packages/xarray/core/variable.py in chunk(self, chunks, name, lock)
#    1063                 chunks = tuple(chunks.get(n, s) for n, s in enumerate(self.shape))
#    1064
# -> 1065             data = da.from_array(data, chunks, name=name, lock=lock, **kwargs)
#    1066
#    1067         return self._replace(data=data)
#
# /home/data/miniconda3/lib/python3.8/site-packages/dask/array/core.py in from_array(x, chunks, name, lock, asarray, fancy, getitem, meta, inline_array)
#    3208         meta = x
#    3209
# -> 3210     return Array(dsk, name, chunks, meta=meta, dtype=getattr(x, "dtype", None))
#    3211
#    3212
#
# /home/data/miniconda3/lib/python3.8/site-packages/dask/array/core.py in __new__(cls, dask, name, chunks, dtype, meta, shape)
#    1149             raise ValueError(CHUNKS_NONE_ERROR_MESSAGE)
#    1150
# -> 1151         self._meta = meta_from_array(meta, ndim=self.ndim, dtype=dtype)
#    1152
#    1153         for plugin in config.get("array_plugins", ()):
#
# /home/data/miniconda3/lib/python3.8/functools.py in __get__(self, instance, owner)
#     965                 val = cache.get(self.attrname, _NOT_FOUND)
#     966                 if val is _NOT_FOUND:
# --> 967                     val = self.func(instance)
#     968                     try:
#     969                         cache[self.attrname] = val
#
# /home/data/miniconda3/lib/python3.8/site-packages/dask/array/core.py in ndim(self)
#    1439     @cached_property
#    1440     def ndim(self):
# -> 1441         return len(self.shape)
#    1442
#    1443     @cached_property
#
# /home/data/miniconda3/lib/python3.8/functools.py in __get__(self, instance, owner)
#     965                 val = cache.get(self.attrname, _NOT_FOUND)
#     966                 if val is _NOT_FOUND:
# --> 967                     val = self.func(instance)
#     968                     try:
#     969                         cache[self.attrname] = val
#
# /home/data/miniconda3/lib/python3.8/site-packages/dask/array/core.py in shape(self)
#    1309     @cached_property
#    1310     def shape(self):
# -> 1311         return tuple(cached_cumsum(c, initial_zero=True)[-1] for c in self.chunks)
#    1312
#    1313     @property
#
# /home/data/miniconda3/lib/python3.8/site-packages/dask/array/core.py in <genexpr>(.0)
#    1309     @cached_property
#    1310     def shape(self):
# -> 1311         return tuple(cached_cumsum(c, initial_zero=True)[-1] for c in self.chunks)
#    1312
#    1313     @property
#
# /home/data/miniconda3/lib/python3.8/site-packages/dask/array/slicing.py in cached_cumsum(seq, initial_zero)
#    1338         # Look up by identity first, to avoid a linear-time __hash__
#    1339         # if we've seen this tuple object before.
# -> 1340         result = _cumsum(_HashIdWrapper(seq), initial_zero)
#    1341     else:
#    1342         # Construct a temporary tuple, and look up by value.
#
# /home/data/miniconda3/lib/python3.8/site-packages/dask/array/slicing.py in _cumsum(seq, initial_zero)
#    1311         seq = seq.wrapped
#    1312     if initial_zero:
# -> 1313         return tuple(accumulate(add, seq, 0))
#    1314     else:
#    1315         return tuple(accumulate(add, seq))
#
# KeyboardInterrupt:
